# %%
    # print("==========================================")
    # print("종합계좌 조회")
    # print("계좌번호 : %s" % accNum)    
    # g_objCpTrade0732.SetInputValue(0,accNum)
    # g_objCpTrade0732.SetInputValue(1,"10")
    # # 0 - (string)계좌번호
    # # 1 - (string)상품관리구분[defaut:50]
    
    # g_objCpTrade0732.BlockRequest()

    # rqStatus = g_objCpTrade0732.GetDibStatus()
    # rqRet = g_objCpTrade0732.GetDibMsg1()
    # print("g_objCpTrade0732 통신상태", rqStatus, rqRet)
       
           
    # print("0  - (string) 계좌번호           : %s" % g_objCpTrade0732.GetHeaderValue(0 ))
    # print("1  - (string) 상품관리구분코드   : %s" % g_objCpTrade0732.GetHeaderValue(1 ))
    # print("2  - (string) 계좌명             : %s" % g_objCpTrade0732.GetHeaderValue(2 ))
    # print("3  - (longlong) 예수금           : %d" % g_objCpTrade0732.GetHeaderValue(3 ))
    # print("4  - (long)미수금                : %d" % g_objCpTrade0732.GetHeaderValue(4 ))
    # print("5  - (long)전일장내현금매도      : %d" % g_objCpTrade0732.GetHeaderValue(5 ))
    # print("6  - (long)전일장내현금매수      : %d" % g_objCpTrade0732.GetHeaderValue(6 ))
    # print("7  - (long)전일신용융자매도      : %d" % g_objCpTrade0732.GetHeaderValue(7 ))
    # print("8  - (long)전일신용융자매수      : %d" % g_objCpTrade0732.GetHeaderValue(8 ))
    # print("9  - (long)전일신용대주매도      : %d" % g_objCpTrade0732.GetHeaderValue(9 ))
    # print("10 - (long)전일신용대주매수      : %d" % g_objCpTrade0732.GetHeaderValue(10))
    # print("11 - (long)전일현금수수료        : %d" % g_objCpTrade0732.GetHeaderValue(11))
    # print("12 - (long)전일현금제세금        : %d" % g_objCpTrade0732.GetHeaderValue(12))
    # print("13 - (long)전일현금정산금        : %d" % g_objCpTrade0732.GetHeaderValue(13))
    # print("14 - (long)전일장외단주매도      : %d" % g_objCpTrade0732.GetHeaderValue(14))
    # print("15 - (long)전일장외단주매수      : %d" % g_objCpTrade0732.GetHeaderValue(15))
    # print("16 - (long)전일장외수수료        : %d" % g_objCpTrade0732.GetHeaderValue(16))
    # print("17 - (long)전일장외제세금        : %d" % g_objCpTrade0732.GetHeaderValue(17))
    # print("18 - (long)전일장외정산금        : %d" % g_objCpTrade0732.GetHeaderValue(18))
    # print("19 - (long)전일합계매도금        : %d" % g_objCpTrade0732.GetHeaderValue(19))
    # print("20 - (long)전일합계매수금        : %d" % g_objCpTrade0732.GetHeaderValue(20))
    # print("21 - (long)전일합계수수료        : %d" % g_objCpTrade0732.GetHeaderValue(21))
    # print("22 - (long)전일합계제세금        : %d" % g_objCpTrade0732.GetHeaderValue(22))
    # print("23 - (long)전일합계정산금        : %d" % g_objCpTrade0732.GetHeaderValue(23))
    # print("24 - (long)전일장내현금신규융자  : %d" % g_objCpTrade0732.GetHeaderValue(24))
    # print("25 - (long)전일신용융자융자상환  : %d" % g_objCpTrade0732.GetHeaderValue(25))
    # print("26 - (long)전일장내현금신규대주  : %d" % g_objCpTrade0732.GetHeaderValue(26))
    # print("27 - (long)전일신용융자대주상환  : %d" % g_objCpTrade0732.GetHeaderValue(27))
    # print("28 - (long)전일장내현금신용상환  : %d" % g_objCpTrade0732.GetHeaderValue(28))
    # print("29 - (long)전일상환융자이자      : %d" % g_objCpTrade0732.GetHeaderValue(29))
    # print("30 - (long)전일상황이용료        : %d" % g_objCpTrade0732.GetHeaderValue(30))
    # print("31 - (long)전일현금거래세        : %d" % g_objCpTrade0732.GetHeaderValue(31))
    # print("32 - (long)전일대주소득세        : %d" % g_objCpTrade0732.GetHeaderValue(32))
    # print("33 - (long)전일대주주민세        : %d" % g_objCpTrade0732.GetHeaderValue(33))
    # print("34 - (long)금일장내현금매도      : %d" % g_objCpTrade0732.GetHeaderValue(34))
    # print("35 - (long)금일장내현금매수      : %d" % g_objCpTrade0732.GetHeaderValue(35))
    # print("36 - (long)금일신용융자매도      : %d" % g_objCpTrade0732.GetHeaderValue(36))
    # print("37 - (long)금일신용융자매수      : %d" % g_objCpTrade0732.GetHeaderValue(37))
    # print("38 - (long)금일신용대주매도      : %d" % g_objCpTrade0732.GetHeaderValue(38))
    # print("39 - (long)금일신용대주매수      : %d" % g_objCpTrade0732.GetHeaderValue(39))
    # print("40 - (long)금일현금수수료        : %d" % g_objCpTrade0732.GetHeaderValue(40))
    # print("41 - (long)금일현금제세금        : %d" % g_objCpTrade0732.GetHeaderValue(41))
    # print("42 - (long)금일현금정산금        : %d" % g_objCpTrade0732.GetHeaderValue(42))
    # print("43 - (long)금일장외단주매도      : %d" % g_objCpTrade0732.GetHeaderValue(43))
    # print("44 - (long)금일장외단주매수      : %d" % g_objCpTrade0732.GetHeaderValue(44))
    # print("45 - (long)금일장외수수료        : %d" % g_objCpTrade0732.GetHeaderValue(45))
    # print("46 - (long)금일장외제세금        : %d" % g_objCpTrade0732.GetHeaderValue(46))
    # print("47 - (long)금일장외정산금        : %d" % g_objCpTrade0732.GetHeaderValue(47))
    # print("48 - (long)금일합계매도금        : %d" % g_objCpTrade0732.GetHeaderValue(48))
    # print("49 - (long)금일합계매수금        : %d" % g_objCpTrade0732.GetHeaderValue(49))
    # print("50 - (long)금일합계수수료        : %d" % g_objCpTrade0732.GetHeaderValue(50))
    # print("51 - (long)금일합계제세금        : %d" % g_objCpTrade0732.GetHeaderValue(51))
    # print("52 - (long)금일합계정산금        : %d" % g_objCpTrade0732.GetHeaderValue(52))
    # print("53 - (long)금일장내현금신규융자  : %d" % g_objCpTrade0732.GetHeaderValue(53))
    # print("54 - (long)금일신용융자융자상환  : %d" % g_objCpTrade0732.GetHeaderValue(54))
    # print("55 - (long)금일장내현금신규대주  : %d" % g_objCpTrade0732.GetHeaderValue(55))
    # print("56 - (long)금일신용융자대주상환  : %d" % g_objCpTrade0732.GetHeaderValue(56))
    # print("57 - (long)금일장내현금신용상환  : %d" % g_objCpTrade0732.GetHeaderValue(57))
    # print("58 - (long)금일상환융자이자      : %d" % g_objCpTrade0732.GetHeaderValue(58))
    # print("59 - (long)금일상황이용료        : %d" % g_objCpTrade0732.GetHeaderValue(59))
    # print("60 - (long)금일현금거래세        : %d" % g_objCpTrade0732.GetHeaderValue(60))
    # print("61 - (long)금일대주소득세        : %d" % g_objCpTrade0732.GetHeaderValue(61))
    # print("62 - (long)금일대주주민세        : %d" % g_objCpTrade0732.GetHeaderValue(62))
    # print("63 - (long) 익일영업일           : %d" % g_objCpTrade0732.GetHeaderValue(63))
    # print("64 - (longlong) 익영업일예수금   : %d" % g_objCpTrade0732.GetHeaderValue(64))
    # print("65 - (long) 결제일               : %d" % g_objCpTrade0732.GetHeaderValue(65))
    # print("66 - (longlong) 결제일예수금     : %d" % g_objCpTrade0732.GetHeaderValue(66))
